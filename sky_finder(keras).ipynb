# %%
import pandas as pd
import cv2
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt 
from skimage import io, transform
import tensorflow as tf
import os

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Go to this URL in a browser: https://accounts.google.com/o/oauth2/auth?client_id=947318989803-6bn6qk8qdgf4n4g3pfee6491hc0brc4i.apps.googleusercontent.com&redirect_uri=urn%3aietf%3awg%3aoauth%3a2.0%3aoob&response_type=code&scope=email%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdocs.test%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive%20https%3a%2f%2fwww.googleapis.com%2fauth%2fdrive.photos.readonly%20https%3a%2f%2fwww.googleapis.com%2fauth%2fpeopleapi.readonly
#
# Enter your authorization code:
# ··········
# Mounted at /content/drive

# %%
data = pd.read_csv("/content/drive/My Drive/SKY_IMAGE/sky_data.csv")

# %%
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/10066.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/10870.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/10917.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/1093.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/11160.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/11331.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/162.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/17218.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/17244.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/18590.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/19106.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/19306.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/19388.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/19834.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/204.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/260.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/3297.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/3395.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/3396.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/3837.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/3888.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/4181.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/4232.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/4584.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/4679.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/4795.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/4801.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/5020.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/5021.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/623.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/65.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/6798.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/684.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/7211.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/7233.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/7371.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/75.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/8438.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/858.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/861.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/8733.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/8953.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/9112.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/9291.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/9483.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/9708.zip
# !wget https://mypages.valdosta.edu/rpmihail/skyfinder/images/9730.zip

# %%
data.head()
# Out:
#               IMAGE_ID          MASK_ID
# 0  20130101_084634.jpg  Masks/10066.png
# 1  20130101_091628.jpg  Masks/10066.png
# 2  20130101_114638.jpg  Masks/10066.png
# 3  20130101_125725.jpg  Masks/10066.png
# 4  20130101_154632.jpg  Masks/10066.png

# %%
from tqdm import tqdm_notebook as tqdm

# %%
for i in tqdm(range(2,47)):
  temp1 = data[(data["MASK_ID"]==label[i])].tail(40)
  temp = pd.concat([temp,temp1],axis=0)

# %%
temp["MASK_ID"].nunique()
# Out:
# 46

# %%
temp.head()
# Out:
#                  IMAGE_ID          MASK_ID
# 1630  20131224_065727.jpg  Masks/10066.png
# 1631  20131224_085726.jpg  Masks/10066.png
# 1632  20131224_105733.jpg  Masks/10066.png
# 1633  20131224_145726.jpg  Masks/10066.png
# 1634  20131224_155724.jpg  Masks/10066.png

# %%
temp["MASK_ID"].nunique()
# Out:
# 47

# %%
def func(x):
  return x.split("/")[1]

# %%
x = temp["MASK_ID"].apply(lambda x: func(x))

# %%
x = pd.DataFrame(x)

# %%
x.head()
# Out:
#      MASK_ID
# 0  10066.png
# 1  10066.png
# 2  10066.png
# 3  10066.png
# 4  10066.png

# %%
def func(x):
  return x.split(".")[0]

# %%
y = pd.DataFrame(x["MASK_ID"].apply(lambda p: func(p)))

# %%
y.head()
# Out:
#   MASK_ID
# 0   10066
# 1   10066
# 2   10066
# 3   10066
# 4   10066

# %%
temp["IMAGE_ID"] = y["MASK_ID"]+"/"+temp["IMAGE_ID"]

# %%
temp.shape
# Out:
# (28365, 2)

# %%
temp.head()
# Out:
#                        IMAGE_ID         MASK_ID
# 83757  9730/20130101_102704.jpg  Masks/9730.png
# 83758  9730/20130101_115703.jpg  Masks/9730.png
# 83759  9730/20130101_172708.jpg  Masks/9730.png
# 83760  9730/20130101_195705.jpg  Masks/9730.png
# 83761  9730/20130102_025704.jpg  Masks/9730.png

# %%
train_masks = temp

# %%
train_masks["MASK_ID"]="/content/drive/My Drive/SKY_IMAGE/"+train_masks["MASK_ID"]

# %%
train_masks.head()
# Out:
#                                                 IMAGE_ID                                           MASK_ID
# 83757  home/mihail/mypages/rpmihail/skyfinder/images/...  /content/drive/My Drive/SKY_IMAGE/Masks/9730.png
# 83758  home/mihail/mypages/rpmihail/skyfinder/images/...  /content/drive/My Drive/SKY_IMAGE/Masks/9730.png
# 83759  home/mihail/mypages/rpmihail/skyfinder/images/...  /content/drive/My Drive/SKY_IMAGE/Masks/9730.png
# 83760  home/mihail/mypages/rpmihail/skyfinder/images/...  /content/drive/My Drive/SKY_IMAGE/Masks/9730.png
# 83761  home/mihail/mypages/rpmihail/skyfinder/images/...  /content/drive/My Drive/SKY_IMAGE/Masks/9730.png

# %%
IMAGE_WIDTH=128
IMAGE_HEIGHT=128
CHANNEL=3
input_shape=(IMAGE_WIDTH, IMAGE_HEIGHT, CHANNEL)
mask_shape=(IMAGE_WIDTH, IMAGE_HEIGHT)
image_size=(IMAGE_WIDTH, IMAGE_HEIGHT)
batch_size=32
epochs=3

# %%
sample = train_masks.sample()
fig=plt.figure(figsize=(16, 8))
for index, s in sample.iterrows():
    original_image = io.imread(s.IMAGE_ID)
    masked_image = io.imread(s.MASK_ID)
    plt.subplot(2, 2, 1)
    plt.imshow(original_image)
    plt.subplot(2, 2, 2)
    plt.imshow(masked_image)

# %%
from skimage.transform import AffineTransform, warp
def shift(image, translation_matrix):
    transformer = AffineTransform(translation=translation_matrix)
    return warp(image, transformer, mode='wrap', preserve_range=True)

# %% [markdown]
# ##DATA AUGUMENTATION
# 1.shifting
# 2.Horizontal flip

# %%
def tranform_image(original_image, mask_image):
    image = original_image
    mask = mask_image
    
    isHorizontalFlip = np.random.random() < 0.5
    isShift = np.random.random() < 0.5

    if isShift:
        translation_matrix = np.random.random_integers(-10, 10), np.random.random_integers(-10, 10)
        image = shift(image, translation_matrix)
        mask = shift(mask, translation_matrix)

    if isHorizontalFlip:
        image = image[:, ::-1]
        mask = mask[:, ::-1]
        
    image = image / 255.0      #rescaling
    mask = mask / 255.0  
    
    return image, mask

# %% [markdown]
# ##DATAGENERATOR

# %%
def data_gen_small(df_data, precess_batch_size, original_image_shape, mask_image_shape):
    while True:
        for k, ix in df_data.groupby(np.arange(len(df_data))//precess_batch_size):
            imgs = []
            labels = []
            for index, row in ix.iterrows():
                # images
                original_img = io.imread(row.IMAGE_ID)
                resized_img = transform.resize(original_img, image_size, mode='constant')
                # masks
                original_mask = io.imread(row.MASK_ID, as_gray=True)
                resized_mask = transform.resize(original_mask, image_size, mode='constant')
                
                image, mask = tranform_image(resized_img, resized_mask)
                
                imgs.append(image)
                labels.append(np.expand_dims(mask, axis=2))
                
            imgs = np.array(imgs)
            labels = np.array(labels)
            yield imgs, labels

# %%
train_gen = data_gen_small(train_masks,batch_size, input_shape, mask_shape)

# %%
fig=plt.figure(figsize=(16, 16))
for i in [1, 2, 3, 4]:
    img, msk = next(train_gen)
    plt.subplot(4, 2, i*2-1)
    plt.imshow(img[0]*255.0)
    plt.subplot(4, 2, i*2)
    plt.imshow(msk[0].reshape(128,128))
# Out:
# /usr/local/lib/python3.6/dist-packages/ipykernel_launcher.py:9: DeprecationWarning: This function is deprecated. Please call randint(-10, 10 + 1) instead
#   if __name__ == '__main__':

# %% [markdown]
# ##MODEL

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Input, concatenate, Conv2D, MaxPooling2D, Activation, UpSampling2D, BatchNormalization

inputs = Input(shape=input_shape)
# 128

down1 = Conv2D(64, (3, 3), padding='same')(inputs)
down1 = BatchNormalization()(down1)
down1 = Activation('relu')(down1)
down1 = Conv2D(64, (3, 3), padding='same')(down1)
down1 = BatchNormalization()(down1)
down1 = Activation('relu')(down1)
down1_pool = MaxPooling2D((2, 2), strides=(2, 2))(down1)
# 64

down2 = Conv2D(128, (3, 3), padding='same')(down1_pool)
down2 = BatchNormalization()(down2)
down2 = Activation('relu')(down2)
down2 = Conv2D(128, (3, 3), padding='same')(down2)
down2 = BatchNormalization()(down2)
down2 = Activation('relu')(down2)
down2_pool = MaxPooling2D((2, 2), strides=(2, 2))(down2)
# 32

down3 = Conv2D(256, (3, 3), padding='same')(down2_pool)
down3 = BatchNormalization()(down3)
down3 = Activation('relu')(down3)
down3 = Conv2D(256, (3, 3), padding='same')(down3)
down3 = BatchNormalization()(down3)
down3 = Activation('relu')(down3)
down3_pool = MaxPooling2D((2, 2), strides=(2, 2))(down3)
# 16

down4 = Conv2D(512, (3, 3), padding='same')(down3_pool)
down4 = BatchNormalization()(down4)
down4 = Activation('relu')(down4)
down4 = Conv2D(512, (3, 3), padding='same')(down4)
down4 = BatchNormalization()(down4)
down4 = Activation('relu')(down4)
down4_pool = MaxPooling2D((2, 2), strides=(2, 2))(down4)
# 8

center = Conv2D(1024, (3, 3), padding='same')(down4_pool)
center = BatchNormalization()(center)
center = Activation('relu')(center)
center = Conv2D(1024, (3, 3), padding='same')(center)
center = BatchNormalization()(center)
center = Activation('relu')(center)
# center

up4 = UpSampling2D((2, 2))(center)
up4 = concatenate([down4, up4], axis=3)
up4 = Conv2D(512, (3, 3), padding='same')(up4)
up4 = BatchNormalization()(up4)
up4 = Activation('relu')(up4)
up4 = Conv2D(512, (3, 3), padding='same')(up4)
up4 = BatchNormalization()(up4)
up4 = Activation('relu')(up4)
up4 = Conv2D(512, (3, 3), padding='same')(up4)
up4 = BatchNormalization()(up4)
up4 = Activation('relu')(up4)
# 16

up3 = UpSampling2D((2, 2))(up4)
up3 = concatenate([down3, up3], axis=3)
up3 = Conv2D(256, (3, 3), padding='same')(up3)
up3 = BatchNormalization()(up3)
up3 = Activation('relu')(up3)
up3 = Conv2D(256, (3, 3), padding='same')(up3)
up3 = BatchNormalization()(up3)
up3 = Activation('relu')(up3)
up3 = Conv2D(256, (3, 3), padding='same')(up3)
up3 = BatchNormalization()(up3)
up3 = Activation('relu')(up3)
# 32

up2 = UpSampling2D((2, 2))(up3)
up2 = concatenate([down2, up2], axis=3)
up2 = Conv2D(128, (3, 3), padding='same')(up2)
up2 = BatchNormalization()(up2)
up2 = Activation('relu')(up2)
up2 = Conv2D(128, (3, 3), padding='same')(up2)
up2 = BatchNormalization()(up2)
up2 = Activation('relu')(up2)
up2 = Conv2D(128, (3, 3), padding='same')(up2)
up2 = BatchNormalization()(up2)
up2 = Activation('relu')(up2)
# 64

up1 = UpSampling2D((2, 2))(up2)
up1 = concatenate([down1, up1], axis=3)
up1 = Conv2D(64, (3, 3), padding='same')(up1)
up1 = BatchNormalization()(up1)
up1 = Activation('relu')(up1)
up1 = Conv2D(64, (3, 3), padding='same')(up1)
up1 = BatchNormalization()(up1)
up1 = Activation('relu')(up1)
up1 = Conv2D(64, (3, 3), padding='same')(up1)
up1 = BatchNormalization()(up1)
up1 = Activation('relu')(up1)
# 128

outputs = Conv2D(1, (1, 1), activation='sigmoid')(up1)

model = Model(inputs=inputs, outputs=outputs)

# %%
optimizer = tf.train.RMSPropOptimizer(0.001)

# %%
from keras import backend as K
def dice_coef(y_true, y_pred, smooth=0):
    y_true_f = K.flatten(y_true)
    y_pred_f = K.flatten(y_pred)
    intersection=K.sum(y_true_f * y_pred_f)
    return(2. * intersection + smooth) / ((K.sum(y_true_f) + K.sum(y_pred_f)) + smooth)

# %%
model.compile(
    optimizer=optimizer, 
    loss="binary_crossentropy", 
    metrics=["accuracy",dice_coef]
)

# %%
steps_per_epoch=np.ceil(float(len(train_masks)) / float(32)).astype(int)
history = model.fit_generator(
    train_gen, 
    steps_per_epoch=steps_per_epoch,
    epochs=1
)
